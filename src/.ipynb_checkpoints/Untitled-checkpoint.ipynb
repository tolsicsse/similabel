# %%
import pandas as pd
from glob import glob
import os
import numpy as np

# %%
drivers = {}
for _ in glob('../data/*.csv'):
    file = os.path.split(_)[-1]
    file_split = file.split('_')
    driver = file_split[0]
    type = os.path.splitext(" ".join(file_split[2:]))[0]
    print(file, driver, type)
    if driver not in drivers:
        drivers[driver] = {}
    if type == 'events':
        events = pd.read_csv(_)
        events = events[['date_time','payload.type']]
        events = events[events["payload.type"].apply(lambda x: x.startswith('Lap'),1)]
        events['Lap'] = events['payload.type'].apply(lambda x: int(x.split("_")[0][-1]))
        events['Lap'][events['payload.type'].apply(lambda x: x.endswith("_end")] = 0
        events_final = []
        for event in events:
            events_final += [{}]
        drivers[driver][type] = 
    else:
        drivers[driver][type] = f"http://localhost:8081/{file}"
# Out:
# 001_Track_driver_input.csv 001 driver input
# 001_Track_events.csv 001 events
# 001_Track_gps_stat.csv 001 gps stat
# 001_Track_imu_msmt.csv 001 imu msmt
# 001_Track_vehspeed_msmt.csv 001 vehspeed msmt
# 001_Track_vehstate_msmt.csv 001 vehstate msmt
# 002_Track_driver_input.csv 002 driver input
# 002_Track_events.csv 002 events
# 002_Track_gps_stat.csv 002 gps stat
# 002_Track_imu_msmt.csv 002 imu msmt
# 002_Track_vehspeed_msmt.csv 002 vehspeed msmt
# 002_Track_vehstate_msmt.csv 002 vehstate msmt
# 003_Track_driver_input.csv 003 driver input
# 003_Track_events.csv 003 events
# 003_Track_gps_stat.csv 003 gps stat
# 003_Track_imu_msmt.csv 003 imu msmt
# 003_Track_vehspeed_msmt.csv 003 vehspeed msmt
# 003_Track_vehstate_msmt.csv 003 vehstate msmt
# 004_Track_driver_input.csv 004 driver input
# 004_Track_events.csv 004 events
# 004_Track_gps_stat.csv 004 gps stat
# 004_Track_imu_msmt.csv 004 imu msmt
# 004_Track_vehspeed_msmt.csv 004 vehspeed msmt
# ...

# %%
drivers
# Out:
# {'001': {'driver input': 'http://localhost:8081/001_Track_driver_input.csv',
#   'gps stat': 'http://localhost:8081/001_Track_gps_stat.csv',
#   'imu msmt': 'http://localhost:8081/001_Track_imu_msmt.csv',
#   'vehspeed msmt': 'http://localhost:8081/001_Track_vehspeed_msmt.csv',
#   'vehstate msmt': 'http://localhost:8081/001_Track_vehstate_msmt.csv'},
#  '002': {'driver input': 'http://localhost:8081/002_Track_driver_input.csv',
#   'gps stat': 'http://localhost:8081/002_Track_gps_stat.csv',
#   'imu msmt': 'http://localhost:8081/002_Track_imu_msmt.csv',
#   'vehspeed msmt': 'http://localhost:8081/002_Track_vehspeed_msmt.csv',
#   'vehstate msmt': 'http://localhost:8081/002_Track_vehstate_msmt.csv'},
#  '003': {'driver input': 'http://localhost:8081/003_Track_driver_input.csv',
#   'gps stat': 'http://localhost:8081/003_Track_gps_stat.csv',
#   'imu msmt': 'http://localhost:8081/003_Track_imu_msmt.csv',
#   'vehspeed msmt': 'http://localhost:8081/003_Track_vehspeed_msmt.csv',
# ...

# %%
import json

# %%
data = []
for k,n in drivers.items():
    n['driver']=k
    data += [{"data":n}]

# %%
json.dumps(data)
# Out:
# '[{"data": {"driver input": "http://localhost:8081/001_Track_driver_input.csv", "events": "http://localhost:8081/001_Track_events.csv", "gps stat": "http://localhost:8081/001_Track_gps_stat.csv", "imu msmt": "http://localhost:8081/001_Track_imu_msmt.csv", "vehspeed msmt": "http://localhost:8081/001_Track_vehspeed_msmt.csv", "vehstate msmt": "http://localhost:8081/001_Track_vehstate_msmt.csv", "driver": "001"}}, {"data": {"driver input": "http://localhost:8081/002_Track_driver_input.csv", "events": "http://localhost:8081/002_Track_events.csv", "gps stat": "http://localhost:8081/002_Track_gps_stat.csv", "imu msmt": "http://localhost:8081/002_Track_imu_msmt.csv", "vehspeed msmt": "http://localhost:8081/002_Track_vehspeed_msmt.csv", "vehstate msmt": "http://localhost:8081/002_Track_vehstate_msmt.csv", "driver": "002"}}, {"data": {"driver input": "http://localhost:8081/003_Track_driver_input.csv", "events": "http://localhost:8081/003_Track_events.csv", "gps stat": "http://localhost:8081/0
# ...

# %%
with open("../drivers.json", "w") as fp:
    json.dump(data, fp)

# %%
events.groupby("Lap", as_index=True).apply(lambda x: NP.ARRAY(x.Lap.values[0], x.date_time.min(), x.date_time.max()]).values
# Out:
# array([list(['Lap1', '2020-09-28 08:09:26.839', '2020-09-28 08:12:12.362']),
#        list(['Lap2', '2020-09-28 08:12:48.802', '2020-09-28 08:15:15.802']),
#        list(['Lap3', '2020-09-28 08:15:40.367', '2020-09-28 08:18:02.575']),
#        list(['Lap4', '2020-09-28 08:23:05.321', '2020-09-28 08:25:41.287']),
#        list(['Lap5', '2020-09-28 08:26:40.936', '2020-09-28 08:28:29.305']),
#        list(['Lap6', '2020-09-28 08:32:06.026', '2020-09-28 08:34:05.376']),
#        list(['Lap7', '2020-09-28 08:35:52.165', '2020-09-28 08:38:13.352'])],
#       dtype=object)

# %%
events
# Out:
#                   date_time payload.type   Lap
# 1   2020-09-28 08:09:26.839   Lap1_start  Lap1
# 2   2020-09-28 08:12:12.362     Lap1_end  Lap1
# 5   2020-09-28 08:12:48.802   Lap2_start  Lap2
# 6   2020-09-28 08:15:15.802     Lap2_end  Lap2
# 9   2020-09-28 08:15:40.367   Lap3_start  Lap3
# 10  2020-09-28 08:18:02.575     Lap3_end  Lap3
# 13  2020-09-28 08:23:05.321   Lap4_start  Lap4
# 14  2020-09-28 08:25:41.287     Lap4_end  Lap4
# 16  2020-09-28 08:26:40.936   Lap5_start  Lap5
# 17  2020-09-28 08:28:29.305     Lap5_end  Lap5
# 20  2020-09-28 08:32:06.026   Lap6_start  Lap6
# 21  2020-09-28 08:34:05.376     Lap6_end  Lap6
# 24  2020-09-28 08:35:52.165   Lap7_start  Lap7
# 25  2020-09-28 08:38:13.352     Lap7_end  Lap7
